# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(columns=["EIN", "NAME"], inplace=True)
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique(axis=0)
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_counts = application_df["APPLICATION_TYPE"].value_counts()
app_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(app_counts[app_counts<528].index)
# application_types_to_replace # to check for values in list

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_counts = application_df["CLASSIFICATION"].value_counts()
class_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_counts[class_counts>1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(class_counts[class_counts<1883].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
numeric_df = pd.get_dummies(application_df)
numeric_df.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                       0
# 1       1   108590              1                       0
# 2       1     5000              0                       0
# 3       1     6692              1                       0
# 4       1   142590              1                       0
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                     1                     0                    0
# 1                     0                     0                    1
# 2                     0                     0                    0
# 3                     0                     0                    1
# 4                     0                     0                    1
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                    0                    0                    0  ...
# ...

# %%
from pandas.core.arrays import numeric
# Split our preprocessed data into our features and target arrays
y = numeric_df['IS_SUCCESSFUL']
X = numeric_df.drop(columns='IS_SUCCESSFUL')

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
X_train_scaled.shape
# Out:
# (25724, 43)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %% [markdown]
# Model 1

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(input_dim=43, units=80, activation='relu')
)
# Second hidden layer
nn.add(
    tf.keras.layers.Dense(input_dim=80, units=30, activation='relu')
)
# Output layer
nn.add(
    tf.keras.layers.Dense(units=1, activation='sigmoid')
)
# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 80)                3520
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# ...
# Total params: 5,981
# Trainable params: 5,981
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 7s 5ms/step - loss: 0.5714 - accuracy: 0.7215
# Epoch 2/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5556 - accuracy: 0.7287
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5517 - accuracy: 0.7309
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5510 - accuracy: 0.7306
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5496 - accuracy: 0.7306
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5481 - accuracy: 0.7320
# Epoch 7/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5471 - accuracy: 0.7341
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5475 - accuracy: 0.7326
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5465 - accuracy: 0.7341
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5580 - accuracy: 0.7292 - 537ms/epoch - 2ms/step
# Loss: 0.5579932928085327, Accuracy: 0.7292128205299377

# %% [markdown]
# Model 2

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

nn02 = tf.keras.models.Sequential()

# First hidden layer
nn02.add(
    tf.keras.layers.Dense(input_dim=43, units=20, activation='relu')
)
# Second hidden layer
nn02.add(
    tf.keras.layers.Dense(input_dim=20, units=15, activation='relu')
)
# Third hidden layer
nn02.add(
    tf.keras.layers.Dense(input_dim=15, units=10, activation='relu')
)
# Output layer
nn02.add(
    tf.keras.layers.Dense(units=1, activation='sigmoid')
)
# Check the structure of the model
nn02.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 20)                880
#
#  dense_4 (Dense)             (None, 15)                315
#
#  dense_5 (Dense)             (None, 10)                160
#
#  dense_6 (Dense)             (None, 1)                 11
#
# ...
# Total params: 1,366
# Trainable params: 1,366
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn02.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
nn02.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 4s 3ms/step - loss: 0.5868 - accuracy: 0.7078
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5578 - accuracy: 0.7281
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5529 - accuracy: 0.7299
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5515 - accuracy: 0.7306
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5501 - accuracy: 0.7304
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5492 - accuracy: 0.7332
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5489 - accuracy: 0.7329
# Epoch 8/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5483 - accuracy: 0.7329
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5472 - accuracy: 0.7334
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss02, model_accuracy02 = nn02.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss02}, Accuracy: {model_accuracy02}")
# Out:
# 268/268 - 1s - loss: 0.5527 - accuracy: 0.7283 - 762ms/epoch - 3ms/step
# Loss: 0.5527434349060059, Accuracy: 0.7282798886299133

# %% [markdown]
# Model 3

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

nn03 = tf.keras.models.Sequential()

# First hidden layer
nn03.add(
    tf.keras.layers.Dense(input_dim=43, units=20, activation='relu')
)
# Second hidden layer
nn03.add(
    tf.keras.layers.Dense(input_dim=20, units=15, activation='relu')
)
# Third hidden layer
nn03.add(
    tf.keras.layers.Dense(input_dim=15, units=10, activation='relu')
)
# Fourth hidden layer
nn03.add(
    tf.keras.layers.Dense(input_dim=10, units=5, activation='relu')
)
# Output layer
nn03.add(
    tf.keras.layers.Dense(units=1, activation='sigmoid')
)
# Check the structure of the model
nn03.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_7 (Dense)             (None, 20)                880
#
#  dense_8 (Dense)             (None, 15)                315
#
#  dense_9 (Dense)             (None, 10)                160
#
#  dense_10 (Dense)            (None, 5)                 55
#
#  dense_11 (Dense)            (None, 1)                 6
#
# ...
# Total params: 1,416
# Trainable params: 1,416
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile and train the model
nn03.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
nn03.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5823 - accuracy: 0.7076
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5572 - accuracy: 0.7259
# Epoch 3/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5541 - accuracy: 0.7283
# Epoch 4/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5521 - accuracy: 0.7305
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5509 - accuracy: 0.7308
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5498 - accuracy: 0.7318
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5489 - accuracy: 0.7319
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5482 - accuracy: 0.7321
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5478 - accuracy: 0.7328
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss03, model_accuracy03 = nn03.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss03}, Accuracy: {model_accuracy03}")
# Out:
# 268/268 - 0s - loss: 0.5588 - accuracy: 0.7278 - 453ms/epoch - 2ms/step
# Loss: 0.5587660074234009, Accuracy: 0.7278134226799011

# %% [markdown]
# ## Optimize Model

# %%
pip install -q keras-tuner
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 3.7 MB/s eta 0:00:00

# %%
import keras_tuner as kt

# %%
# make a function that will create a single sequential model with hyperparameter options
# options include - choices of activation functions between layers, number of neurons on layers, number of layers

def make_model(hp): # hyperparameters that will be passed in from a Hyperband tuner variable

  # set up the sequential model
  nn_model = tf.keras.models.Sequential()

  # set up choices for the activation functions to be used in the hidden layers
  activation_list = hp.Choice('activation', ['relu', 'tanh', 'sigmoid'])

  # set up the keras tuner to decide (loop) through a number of attributes in the first layer - input_dim = 43 - loop through 1 - 20 neurons on the second layer
  nn_model.add(
      tf.keras.layers.Dense(
          input_dim=43,
          activation=activation_list,
          units=hp.Int('first_units', min_value=1, max_value=20) # this will loop through 1 - 20
      )
  )

  # set up the keras tuner to test different number of hidden layers as well as neurons on those hidden layers
  for num in range(hp.Int('num_layers', 1, 11)):

    # add the layer (or layers) with a neuron (or neurons) on each layer
    nn_model.add(
        tf.keras.layers.Dense(
            activation=activation_list,
            units=hp.Int(
                'units_' + str(num),
                min_value=1,
                max_value=20
                )
        )

    )

  # set up the output layer (1 node)
  nn_model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

  # compile the model
  nn_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

  # return the model to be used in the iteration
  return nn_model

# %%
# use the Hyperband function in order to run the optimizer function
tuner_model = kt.Hyperband(
    # pass in the function that contains the attributes
    make_model,
    # pass in the val_accuracy objective function
    objective = 'val_accuracy', # tries to find the highest accuracy of the combination of hyperparameters
    # tell the max_epochs
    max_epochs = 50, # lower number so it doesn't take forever
    # tell the number of hyperband iterations
    hyperband_iterations=2
)

# %%
tuner_model.search(X_train_scaled, y_train, epochs=50, validation_data=[X_test_scaled, y_test])
# Out:
# Trial 180 Complete [00h 02m 23s]
# val_accuracy: 0.7306122183799744
#
# Best val_accuracy So Far: 0.7336443066596985
# Total elapsed time: 02h 02m 24s

# %%
# use .get_best_hyperparameters
tuner_model.get_best_hyperparameters(1)[0].values
# Out:
# {'activation': 'sigmoid',
#  'first_units': 15,
#  'num_layers': 2,
#  'units_0': 2,
#  'units_1': 18,
#  'units_2': 3,
#  'units_3': 1,
#  'units_4': 19,
#  'units_5': 4,
#  'units_6': 7,
#  'units_7': 13,
#  'units_8': 18,
#  'units_9': 13,
#  'units_10': 6,
#  'tuner/epochs': 50,
#  'tuner/initial_epoch': 17,
#  'tuner/bracket': 3,
#  'tuner/round': 3,
#  'tuner/trial_id': '0137'}

# %%
# use .get_best_models to extract the hyperparameters and evaluate the model loss and accuracy
best_model = tuner_model.get_best_models(1)[0]

best_model_loss, best_model_accuracy = best_model.evaluate(X_test_scaled, y_test)
# Out:
# 268/268 [==============================] - 1s 2ms/step - loss: 0.5616 - accuracy: 0.7336

# %%
# Export our model to HDF5 file
# import the save model module from keras.models
from tensorflow.keras.models import save_model
# export the best deep learning model as an H5 file
best_model.save('best_dl_model.h5')
